# %% [markdown]
# <a href="https://colab.research.google.com/github/saitejachava2/SOH_NASA/blob/main/EDA_of_SOH_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
import os
import glob
import seaborn as sns

# %% [markdown]
# loading dataset

# %%
data = pd.read_csv('/content/ddd1.csv')
df = pd.DataFrame(data)
df
# Out:
#            time  terminal_voltage  ...  capacity  temperature
# 0         0.000          4.199360  ...  1.891052    23.937044
# 1        16.781          4.199497  ...  1.891052    23.924074
# 2        35.703          3.985606  ...  1.891052    24.004257
# 3        53.781          3.963247  ...  1.891052    24.162868
# 4        71.922          3.946647  ...  1.891052    24.346368
# ...         ...               ...  ...       ...          ...
# 50280  2781.312          3.336677  ...  1.432455    38.744012
# 50281  2791.062          3.349952  ...  1.432455    38.462399
# 50282  2800.828          3.362104  ...  1.432455    38.246805
# 50283  2810.640          3.373357  ...  1.432455    37.970504
# 50284  2820.390          3.383857  ...  1.432455    37.851602
#
# [50285 rows x 10 columns]

# %%
print("Shape of data :", np.shape(data))
# Out:
# Shape of data : (50285, 10)

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(12, 8))

plt.scatter(data['cycle'], data['SOH'])
plt.plot(data['cycle'], len(data['cycle'])*[0.75], color = 'r')

plt.ylabel('SOH', fontsize = 15)
plt.xlabel('cycles', fontsize = 15)
plt.title('SOH vs cycles', fontsize = 15)
plt.show()

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(12, 8))

plt.scatter(data['cycle'], data['capacity'])
plt.plot(data['cycle'], len(data['cycle'])*[1.5], color = 'r')

plt.ylabel('capacity', fontsize = 15)
plt.xlabel('cycles', fontsize = 15)
plt.title('cycle vs capacity', fontsize = 15)
plt.show()

# %% [markdown]
# calculation of SOH

# %%
capacity = df['capacity']

SOH = capacity/2
print("Max of SOH :", np.max(SOH))
print("Min of SOH :",  np.min(SOH))
# Out:
# Max of SOH : 0.9455261475
# Min of SOH : 0.70022762

# %%
data = data.drop(["A.sec","A.h","SOC"],axis=1)

# %%
n = 50088
data.drop(data.tail(n).index,
        inplace = True)

# %%
print(data)
# Out:
#          time  terminal_voltage  terminal_current  ...  cycle  capacity  temperature
# 0       0.000          4.199360         -0.001866  ...      1  1.891052    23.937044
# 1      16.781          4.199497         -0.002139  ...      1  1.891052    23.924074
# 2      35.703          3.985606         -1.988778  ...      1  1.891052    24.004257
# 3      53.781          3.963247         -1.992558  ...      1  1.891052    24.162868
# 4      71.922          3.946647         -1.988491  ...      1  1.891052    24.346368
# ..        ...               ...               ...  ...    ...       ...          ...
# 192  3608.594          3.008150         -0.004887  ...      1  1.891052    38.799820
# 193  3628.953          3.025277         -0.002660  ...      1  1.891052    38.414898
# 194  3649.375          3.039514         -0.004481  ...      1  1.891052    38.050707
# 195  3669.875          3.051826         -0.008851  ...      1  1.891052    37.693582
# ...

# %% [markdown]
# Time vs current

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(12, 8))

plt.plot(data['time'], data['terminal_current'])


plt.ylabel('terminal_current', fontsize = 15)
plt.xlabel('time', fontsize = 15)
plt.title('current vs time', fontsize = 15)
plt.show()

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(12, 8))

plt.plot(data['time'], data['terminal_voltage'])


plt.ylabel('terminal_voltage', fontsize = 15)
plt.xlabel('time', fontsize = 15)
plt.title('voltage vs time', fontsize = 15)
plt.show()
