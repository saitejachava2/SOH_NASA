# %% [markdown]
# <a href="https://colab.research.google.com/github/saitejachava2/SOH_NASA/blob/main/EDA_for_SOH2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
import os
import glob
import seaborn as sns

# %%
data = pd.read_csv('/content/dd2.csv')
df = pd.DataFrame(data)
df
# Out:
#        terminal_voltage  terminal_current  ...         A.h           SOC
# 0              4.191492         -0.004902  ...    0.000000    100.000000
# 1              4.190749         -0.001478  ...   -0.000023     99.998769
# 2              3.974871         -2.012528  ...   -0.000031     99.998351
# 3              3.951717         -2.013979  ...   -0.010137     99.453976
# 4              3.934352         -2.011144  ...   -0.020286     98.907311
# ...                 ...               ...  ...         ...           ...
# 50280          3.579262         -0.001569  ... -264.499245 -19861.012100
# 50281          3.581964         -0.003067  ... -264.499249 -19861.012420
# 50282          3.584484         -0.003079  ... -264.499258 -19861.013050
# 50283          3.587336          0.001219  ... -264.499266 -19861.013680
# 50284          3.589937         -0.000583  ... -264.499263 -19861.013430
#
# [50285 rows x 10 columns]

# %%
print("Shape of data :", np.shape(data))
# Out:
# Shape of data : (50285, 10)

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(12, 8))

plt.scatter(data['cycle'], data['SOH'])
plt.plot(data['cycle'], len(data['cycle'])*[0.75], color = 'r')

plt.ylabel('SOH', fontsize = 15)
plt.xlabel('cycles', fontsize = 15)
plt.title('SOH vs cycles', fontsize = 15)
plt.show()

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(12, 8))

plt.scatter(data['cycle'], data['capacity'])
plt.plot(data['cycle'], len(data['cycle'])*[1.5], color = 'r')

plt.ylabel('capacity', fontsize = 15)
plt.xlabel('cycles', fontsize = 15)
plt.title('cycle vs capacity', fontsize = 15)
plt.show()

# %%
capacity = df['capacity']

SOH = capacity/2
print("Max of SOH :", np.max(SOH))
print("Min of SOH :",  np.min(SOH))
# Out:
# Max of SOH : 0.9282437105
# Min of SOH : 0.643726261

# %%
data = data.drop(["A.sec","A.h","SOC"],axis=1)

# %%
n = 50088
data.drop(data.tail(n).index,
        inplace = True)

# %%
print(data)
# Out:
#      terminal_voltage  terminal_current  temperature  ...  capacity       SOH  cycle
# 0            4.191492         -0.004902    24.330034  ...  1.856487  0.928244      1
# 1            4.190749         -0.001478    24.325993  ...  1.856487  0.928244      1
# 2            3.974871         -2.012528    24.389085  ...  1.856487  0.928244      1
# 3            3.951717         -2.013979    24.544752  ...  1.856487  0.928244      1
# 4            3.934352         -2.011144    24.731385  ...  1.856487  0.928244      1
# ..                ...               ...          ...  ...       ...       ...    ...
# 192          3.258705         -0.001513    35.296711  ...  1.856487  0.928244      1
# 193          3.264121         -0.001532    35.021738  ...  1.856487  0.928244      1
# 194          3.269030         -0.000406    34.754871  ...  1.856487  0.928244      1
# 195          3.273207         -0.000388    34.490078  ...  1.856487  0.928244      1
# 196          3.277170         -0.006528    34.230853  ...  1.856487  0.928244      1
#
# [197 rows x 7 columns]

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(12, 8))

plt.plot(data['time'], data['terminal_current'])


plt.ylabel('terminal_current', fontsize = 15)
plt.xlabel('time', fontsize = 15)
plt.title('current vs time', fontsize = 15)
plt.show()

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(12, 8))

plt.plot(data['time'], data['terminal_voltage'])


plt.ylabel('terminal_voltage', fontsize = 15)
plt.xlabel('time', fontsize = 15)
plt.title('voltage vs time', fontsize = 15)
plt.show()
